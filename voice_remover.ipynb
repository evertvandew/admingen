# %%
from scipy.io import wavfile
freq, orig = wavfile.read('/home/ehwaal/tmp/tracks/Jesus I Need You - Hillsong Worship-lKM-8CZRplI.wav')

# %%
mono = orig[:,0] - orig[:,1]

# %%
wavfile.write('/home/ehwaal/tmp/tracks/simple.wav', freq, mono)

# %%
import matplotlib.pyplot as plt
plt.plot(mono)
